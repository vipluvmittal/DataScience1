# %%
import pandas as pd
data = pd.DataFrame({'boy': ['b1', 'b1', 'b2','b3'],
                 'girl': ['g4','g5','g3','g2']})
data
# Out:
#   boy girl
# 0  b1   g4
# 1  b1   g5
# 2  b2   g3
# 3  b3   g2

# %%
data.sort_values(by=['boy','girl'], ascending=[False, True], inplace=True)
data
# Out:
#   boy girl
# 3  b3   g2
# 2  b2   g3
# 0  b1   g4
# 1  b1   g5

# %%
import pandas as pd
data = pd.DataFrame({'k1': ['one'] * 5 + ['two'] * 6, 'k2': [3, 2, 1,3,2, 3, 3, 4, 4,4,3]})

# %%
data.sort_values(by='k2')
data
# Out:
#      k1  k2
# 0   one   3
# 1   one   2
# 2   one   1
# 3   one   3
# 4   one   2
# 5   two   3
# 6   two   3
# 7   two   4
# 8   two   4
# 9   two   4
# 10  two   3

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 3  two   3
# 5  two   4

# %%
mov = np.loadtxt('movies.dat')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-288849b5432e> in <module>()
# ----> 1 mov = np.loadtxt('movies.dat')
#
# NameError: name 'np' is not defined

# %%
df = pd.read_csv('C:\Users\VIPLUV\Desktop\Book2.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-23-6928448f0108> in <module>()
# ----> 1 df = pd.read_csv('C:\Users\VIPLUV\Desktop\Book2.csv')
#       2 df.head()
#
# ...

# %%
df = pd.read_csv('C:\Users\VIPLUV\Desktop')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-22-046880fcf5ce> in <module>()
# ----> 1 df = pd.read_csv('C:\Users\VIPLUV\Desktop')
#
# ...

# %%
df = pd.read_csv('C:\Users\VIPLUV\Desktop\Book2.csv')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-24-5fb10f9c80ac> in <module>()
# ----> 1 df = pd.read_csv('C:\Users\VIPLUV\Desktop\Book2.csv')
#
# ...

# %%
pd.read_csv('C:\Users\VIPLUV\Desktop\Book2.csv')
# Out:
#        1::Toy Story (1995)::Animation|Children's|Comedy
# 0       2::Jumanji (1995)::Adventure|Children's|Fantasy
# 1            3::Grumpier Old Men (1995)::Comedy|Romance
# 2             4::Waiting to Exhale (1995)::Comedy|Drama
# 3         5::Father of the Bride Part II (1995)::Comedy
# 4                 6::Heat (1995)::Action|Crime|Thriller
# 5                     7::Sabrina (1995)::Comedy|Romance
# 6          8::Tom and Huck (1995)::Adventure|Children's
# 7                        9::Sudden Death (1995)::Action
# 8       10::GoldenEye (1995)::Action|Adventure|Thriller
# 9     11::American President, The (1995)::Comedy|Dra...
# 10    12::Dracula: Dead and Loving It (1995)::Comedy...
# 11               13::Balto (1995)::Animation|Children's
# 12                              14::Nixon (1995)::Drama
# 13    15::Cutthroat Island (1995)::Action|Adventure|...
# 14                    16::Casino (1995)::Drama|Thriller
# 15      17::Sense and Sensibility (1995)::Drama|Romance
# ...

# %%
pd.read_csv('C:\Users\VIPLUV\Desktop\Book1.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b93a9c25def1> in <module>()
# ----> 1 pd.read_csv('C:\Users\VIPLUV\Desktop\Book1.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
pd.read_csv('C:\Users\VIPLUV\Desktop\Book1.csv')
# Out:
#        SNO  Unnamed: 1                                         Movie Name  \
# 0        1         NaN                                   Toy Story (1995)
# 1        2         NaN                                     Jumanji (1995)
# 2        3         NaN                            Grumpier Old Men (1995)
# 3        4         NaN                           Waiting to Exhale (1995)
# 4        5         NaN                 Father of the Bride Part II (1995)
# 5        6         NaN                                        Heat (1995)
# 6        7         NaN                                     Sabrina (1995)
# 7        8         NaN                                Tom and Huck (1995)
# 8        9         NaN                                Sudden Death (1995)
# 9       10         NaN                                   GoldenEye (1995)
# 10      11         NaN                     American President, The (1995)
# 11      12         NaN                                            Dracula
# ...
